# %% [markdown]
# ## Governor Scrape from Wikipedia

# %% [markdown]
# <p> * Data for state governors current as of 3/26/2020 </p>

# %%
# Import dependencies
import pandas as pd

# %%
# Wikipedia URL of state governors
governor_url = "https://en.wikipedia.org/wiki/List_of_United_States_governors"

# %%
# Scrape tabular data from Wikipedia page with pandas
governors = pd.read_html(governor_url)
governors_df = pd.DataFrame(governors[0])

# %%
# Rename columns for clarity
governors_df.columns = ["State", "Portrait", "Governor", "Party", "Party.1", "Born", "Prior Public Experience",
                        "Inauguration", "End of term", "Past governors", "Unnamed: 10_level-1"]

# %%
# Keep only state, governor, party affiliation columns
governors_df1 = governors_df[["State", "Governor", "Party.1", "Inauguration", "End of term"]]
governors_df2 = governors_df1.rename(columns={"Party.1": "Party"})

# Clean up party affiliations
governors_df2 = governors_df2.set_index("State")
governors_df2.loc["Minnesota", "Party"] = "Democratic"
governors_df2.loc["West Virginia", "Party"] = "Republican"

# Create new column for term limit information
def termed(row):
    if "limits" in row["End of term"]:
        return True
    elif "retiring" in row["End of term"]:
        return True
    else:
        return False
    
governors_df2["Term limit"] = governors_df2.apply(termed, axis=1)

# New column for year of inauguration and refactor end of term
governors_df2["Beginning of Term"] = governors_df2["Inauguration"].str[-4:].map(int)

def split_term(my_str):
    return int(str(my_str)[0:4])

governors_df2["End of term"] = governors_df2["End of term"].map(split_term)

# Final dataframe
governors_df_clean = governors_df2
governors_df_clean
# Out:
#                               Governor       Party       Inauguration  \
# State
# Alabama                       Kay Ivey  Republican     April 10, 2017
# Alaska                   Mike Dunleavy  Republican   December 3, 2018
# Arizona                     Doug Ducey  Republican    January 5, 2015
# Arkansas                Asa Hutchinson  Republican   January 13, 2015
# California                Gavin Newsom  Democratic    January 7, 2019
# Colorado                   Jared Polis  Democratic    January 8, 2019
# Connecticut                 Ned Lamont  Democratic    January 9, 2019
# Delaware                   John Carney  Democratic   January 17, 2017
# Florida                   Ron DeSantis  Republican    January 8, 2019
# Georgia                     Brian Kemp  Republican   January 14, 2019
# Hawaii                       David Ige  Democratic   December 1, 2014
# Idaho                      Brad Little  Republican    January 7, 2019
# Illinois                J. B. Pritzker  Democratic   January 14, 2019
# Indiana                   Eric Holcomb  Republican    January 9, 2017
# Iowa                      Kim Reynolds  Republican       May 24, 2017
# Kansas                     Laura Kelly  Democratic   January 14, 2019
# Kentucky                  Andy Beshear  Democratic  December 10, 2019
# Louisiana             John Bel Edwards  Democratic   January 11, 2016
# Maine                      Janet Mills  Democratic    January 2, 2019
# Maryland                   Larry Hogan  Republican   January 21, 2015
# Massachusetts            Charlie Baker  Republican    January 8, 2015
# Michigan              Gretchen Whitmer  Democratic    January 1, 2019
# Minnesota                     Tim Walz  Democratic    January 7, 2019
# Mississippi                Tate Reeves  Republican   January 14, 2020
# Missouri                   Mike Parson  Republican       June 1, 2018
# Montana                  Steve Bullock  Democratic    January 7, 2013
# Nebraska                 Pete Ricketts  Republican    January 8, 2015
# Nevada                   Steve Sisolak  Democratic    January 7, 2019
# New Hampshire             Chris Sununu  Republican    January 5, 2017
# New Jersey                 Phil Murphy  Democratic   January 16, 2018
# New Mexico      Michelle Lujan Grisham  Democratic    January 1, 2019
# New York                  Andrew Cuomo  Democratic    January 1, 2011
# North Carolina              Roy Cooper  Democratic    January 1, 2017
# North Dakota               Doug Burgum  Republican  December 15, 2016
# Ohio                       Mike DeWine  Republican   January 14, 2019
# Oklahoma                   Kevin Stitt  Republican   January 14, 2019
# Oregon                      Kate Brown  Democratic  February 18, 2015
# Pennsylvania                  Tom Wolf  Democratic   January 20, 2015
# Rhode Island             Gina Raimondo  Democratic    January 6, 2015
# South Carolina          Henry McMaster  Republican   January 24, 2017
# South Dakota               Kristi Noem  Republican    January 5, 2019
# Tennessee                     Bill Lee  Republican   January 19, 2019
# Texas                      Greg Abbott  Republican   January 20, 2015
# Utah                      Gary Herbert  Republican    August 11, 2009
# Vermont                     Phil Scott  Republican    January 5, 2017
# Virginia                 Ralph Northam  Democratic   January 13, 2018
# Washington                  Jay Inslee  Democratic   January 16, 2013
# West Virginia              Jim Justice  Republican   January 16, 2017
# Wisconsin                   Tony Evers  Democratic    January 7, 2019
# Wyoming                    Mark Gordon  Republican    January 7, 2019
#
#                 End of term  Term limit  Beginning of Term
# State
# Alabama                2023       False               2017
# Alaska                 2022       False               2018
# Arizona                2023        True               2015
# Arkansas               2023        True               2015
# California             2023       False               2019
# Colorado               2023       False               2019
# Connecticut            2023       False               2019
# Delaware               2021       False               2017
# Florida                2023       False               2019
# Georgia                2023       False               2019
# Hawaii                 2022        True               2014
# Idaho                  2023       False               2019
# Illinois               2023       False               2019
# Indiana                2021       False               2017
# Iowa                   2023       False               2017
# Kansas                 2023       False               2019
# Kentucky               2023       False               2019
# Louisiana              2024        True               2016
# Maine                  2023       False               2019
# Maryland               2023        True               2015
# Massachusetts          2023       False               2015
# Michigan               2023       False               2019
# Minnesota              2023       False               2019
# Mississippi            2024       False               2020
# Missouri               2021       False               2018
# Montana                2021        True               2013
# Nebraska               2023        True               2015
# Nevada                 2023       False               2019
# New Hampshire          2021       False               2017
# New Jersey             2022       False               2018
# New Mexico             2023       False               2019
# New York               2022       False               2011
# North Carolina         2021       False               2017
# North Dakota           2020       False               2016
# Ohio                   2023       False               2019
# Oklahoma               2023       False               2019
# Oregon                 2023        True               2015
# Pennsylvania           2023        True               2015
# Rhode Island           2023        True               2015
# South Carolina         2023       False               2017
# South Dakota           2023       False               2019
# Tennessee              2023       False               2019
# Texas                  2023       False               2015
# Utah                   2021        True               2009
# Vermont                2021       False               2017
# Virginia               2022        True               2018
# Washington             2021       False               2013
# West Virginia          2021       False               2017
# Wisconsin              2023       False               2019
# Wyoming                2023       False               2019

# %% [markdown]
# ### Create Database Connection

# %%
# Import dependencies
from config import user, password

# Import sqlalchemy to connect to database
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, Column, Integer, String, Float, func
import psycopg2

# %%
# Create ORM class
Base = declarative_base()

class Governors(Base):
    __tablename__="governors"
    governor_id = Column(Integer, primary_key = True, autoincrement=True)
    governor = Column(String(50))
    state = Column(String(20))
    party = Column(String(20))
    inauguration = Column(String(50))
    term_begin = Column(Integer)
    term_end = Column(Integer)
    term_limit = Column(String(10))

# %%
# Create database connection
engine = create_engine(f"postgresql://{user}:{password}@localhost:5432/Twitter_COVID19")
conn = engine.connect
Base.metadata.create_all(engine)
session = Session(bind=engine)

# %%
# Import dataframe into database
governors_df_clean = governors_df_clean.reset_index()
governors_df_clean

for index, row in governors_df_clean.iterrows():
    data = Governors(governor = row["Governor"], 
                     state = row["State"], 
                     party = row["Party"],
                     inauguration = row["Inauguration"],
                     term_begin = row["Beginning of Term"],
                     term_end = row["End of term"],
                     term_limit = row["Term limit"])
    session.add(data)
    session.commit()
    
session.close()
